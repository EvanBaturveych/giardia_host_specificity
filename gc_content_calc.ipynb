# %%
from collections import Counter

def parse_fasta_file(input_filepath, max_lines=5000):  
    with open(input_filepath) as input_file:
        label = None
        seq = ""

        for line in input_file:
            line = line.strip()
            if line.startswith(">"):
                if label is not None and len(seq) > 300:
                    yield label, seq
                label = line[1:]  
                seq = ""
            else:
                seq += line

        if label is not None and len(seq) > 300:
            yield label, seq



def calc_gc_content(seq):
    seq = seq.upper()
    g_count = seq.count("G")
    c_count = seq.count("C")
    gc_total = g_count + c_count
    return gc_total / len(seq) if len(seq) > 0 else 0.0






def analyze_fasta(input_filepath):
    fasta_entries = parse_fasta_file(input_filepath, max_lines=5000) 

    print("Here are the results:\n")

    for label, seq in fasta_entries:
        seq = seq.replace("\n", "").replace(" ", "")
        seq_length = len(seq)
        gc = calc_gc_content(seq)

        print(f"Label: {label.strip()}")
        print(f"Total length = {seq_length} | GC content: {gc:.2%}")
        print(f"Sequence length (bp): {seq_length}")
       


input_filepath = "isolate_A/Isolate_A_annotated.fasta"
analyze_fasta(input_filepath)
# Out:
# Here are the results:
#
# Label: DHA2_10013-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000017:3703-4365(+) | length=663 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 663 | GC content: 48.11%
# Sequence length (bp): 663
# Label: DHA2_10016-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000017:6342-7277(-) | length=936 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 936 | GC content: 50.75%
# Sequence length (bp): 936
# Label: DHA2_10019-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Phospholipid-transporting ATPase | location=AHGT01000017:9901-14583(-) | length=4683 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 4683 | GC content: 48.45%
# Sequence length (bp): 4683
# Label: DHA2_10025-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000024:115371-116096(+) | length=726 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 726 | GC content: 51.52%
# Sequence length (bp): 726
# Label: DHA2_10027-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Chromosome segregation protein SMC | location=AHGT01000050:36022-36540(+) | length=519 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 519 | GC content: 44.89%
# Sequence length (bp): 519
# Label: DHA2_10033-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000050:32175-33098(-) | length=924 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 924 | GC content: 47.62%
# Sequence length (bp): 924
# Label: DHA2_10034-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000050:25963-32163(+) | length=6201 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 6201 | GC content: 45.19%
# Sequence length (bp): 6201
# Label: DHA2_10038-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000050:22743-23603(+) | length=861 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 861 | GC content: 46.81%
# Sequence length (bp): 861
# Label: DHA2_10055-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=RNA polymerase I, and III, AC40 subunit | location=AHGT01000079:25880-26932(-) | length=1053 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1053 | GC content: 48.62%
# Sequence length (bp): 1053
# Label: DHA2_10056-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Rho-like GTPase actvator protein | location=AHGT01000079:25271-25867(-) | length=597 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 597 | GC content: 47.57%
# Sequence length (bp): 597
# Label: DHA2_10073-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000079:13028-13999(-) | length=972 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 972 | GC content: 51.65%
# Sequence length (bp): 972
# Label: DHA2_100845-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Lipase | location=AHGT01000072:4503-5789(+) | length=1287 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1287 | GC content: 47.32%
# Sequence length (bp): 1287
# Label: DHA2_100864-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Vacuolar protein sorting/targeting protein VPS26 | location=AHGT01000088:28845-30440(+) | length=1596 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1596 | GC content: 52.38%
# Sequence length (bp): 1596
# Label: DHA2_100906-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Dynein heavy chain | location=AHGT01000031:35870-52522(-) | length=16653 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 16653 | GC content: 49.26%
# Sequence length (bp): 16653
# Label: DHA2_10091-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ribosomal protein L14p/L23e | location=AHGT01000086:15557-15985(+) | length=429 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 429 | GC content: 57.81%
# Sequence length (bp): 429
# Label: DHA2_100955-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Mitotic spindle checkpoint component MAD2 | location=AHGT01000015:5321-5932(-) | length=612 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 612 | GC content: 52.78%
# Sequence length (bp): 612
# Label: DHA2_100959-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Methyltransferase | location=AHGT01000015:13053-14024(+) | length=972 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 972 | GC content: 47.02%
# Sequence length (bp): 972
# Label: DHA2_101138-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Dynein heavy chain | location=AHGT01000039:45946-61437(-) | length=15492 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 15492 | GC content: 49.23%
# Sequence length (bp): 15492
# Label: DHA2_101168-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ankyrin repeat protein | location=AHGT01000010:31455-34820(-) | length=3366 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3366 | GC content: 48.34%
# Sequence length (bp): 3366
# Label: DHA2_101278-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000020:36634-40626(-) | length=3993 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3993 | GC content: 51.16%
# Sequence length (bp): 3993
# Label: DHA2_101339-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Peptidyl-prolyl cis-trans isomerase | location=AHGT01000034:4676-5323(+) | length=648 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 648 | GC content: 47.22%
# Sequence length (bp): 648
# Label: DHA2_10137-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Kinesin motor domain protein | location=AHGT01000091:33109-35379(+) | length=2271 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2271 | GC content: 47.34%
# Sequence length (bp): 2271
# Label: DHA2_10139-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000091:31455-32774(+) | length=1320 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1320 | GC content: 48.48%
# Sequence length (bp): 1320
# Label: DHA2_10141-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000091:29755-30960(-) | length=1206 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1206 | GC content: 47.01%
# Sequence length (bp): 1206
# Label: DHA2_101501-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Seryl-tRNA synthetase | location=AHGT01000002:198619-199992(-) | length=1374 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1374 | GC content: 48.76%
# Sequence length (bp): 1374
# Label: DHA2_101594-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative nucleic acid-binding protein | location=AHGT01000008:10050-13229(+) | length=3180 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3180 | GC content: 48.30%
# Sequence length (bp): 3180
# Label: DHA2_10167-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Chromosome segregation protein SMC | location=AHGT01000051:44287-47859(+) | length=3573 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3573 | GC content: 51.19%
# Sequence length (bp): 3573
# Label: DHA2_101768-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000024:11263-11781(-) | length=519 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 519 | GC content: 46.24%
# Sequence length (bp): 519
# Label: DHA2_10181-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000013:90278-92554(+) | length=2277 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2277 | GC content: 48.00%
# Sequence length (bp): 2277
# Label: DHA2_101810-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Phospholipid-transporting ATPase | location=AHGT01000012:11136-15434(+) | length=4299 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 4299 | GC content: 47.78%
# Sequence length (bp): 4299
# Label: DHA2_10182-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000013:92575-93069(+) | length=495 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 495 | GC content: 54.34%
# Sequence length (bp): 495
# Label: DHA2_101850-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine protein kinase | location=AHGT01000011:7459-8673(+) | length=1215 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1215 | GC content: 46.50%
# Sequence length (bp): 1215
# Label: DHA2_101906-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative AAA family protein | location=AHGT01000062:4379-5743(-) | length=1365 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1365 | GC content: 53.85%
# Sequence length (bp): 1365
# Label: DHA2_101918-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000045:1602-2561(-) | length=960 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 960 | GC content: 47.71%
# Sequence length (bp): 960
# Label: DHA2_101919-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=5'-AMP-activated protein kinase, beta subunit | location=AHGT01000045:3541-4278(+) | length=738 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 738 | GC content: 52.71%
# Sequence length (bp): 738
# Label: DHA2_101943-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000038:92585-93277(-) | length=693 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 693 | GC content: 47.19%
# Sequence length (bp): 693
# Label: DHA2_101955-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000020:123076-125370(+) | length=2295 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2295 | GC content: 50.11%
# Sequence length (bp): 2295
# Label: DHA2_10196-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000013:103396-103890(+) | length=495 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 495 | GC content: 54.75%
# Sequence length (bp): 495
# Label: DHA2_102023-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ankyrin repeat protein | location=AHGT01000098:4646-7159(-) | length=2514 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2514 | GC content: 49.36%
# Sequence length (bp): 2514
# Label: DHA2_102034-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ankyrin repeat protein | location=AHGT01000002:265905-268841(-) | length=2937 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2937 | GC content: 48.21%
# Sequence length (bp): 2937
# Label: DHA2_102056-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000002:219430-225663(-) | length=6234 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 6234 | GC content: 44.42%
# Sequence length (bp): 6234
# Label: DHA2_102101-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Kinesin-like protein | location=AHGT01000029:30027-33092(+) | length=3066 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3066 | GC content: 55.84%
# Sequence length (bp): 3066
# Label: DHA2_102108-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Clathrin heavy chain | location=AHGT01000029:53701-59316(+) | length=5616 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 5616 | GC content: 51.89%
# Sequence length (bp): 5616
# Label: DHA2_102170-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000022:109028-109786(+) | length=759 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 759 | GC content: 47.96%
# Sequence length (bp): 759
# Label: DHA2_102184-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000007:181824-189449(-) | length=7626 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 7626 | GC content: 47.67%
# Sequence length (bp): 7626
# Label: DHA2_102248-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Chromosome segregation protein SMC | location=AHGT01000001:409040-412108(-) | length=3069 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3069 | GC content: 47.18%
# Sequence length (bp): 3069
# Label: DHA2_10231-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative TCP-1/cpn60 chaperonin family protein | location=AHGT01000031:77696-79375(-) | length=1680 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1680 | GC content: 51.61%
# Sequence length (bp): 1680
# Label: DHA2_10232-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000031:79436-81445(-) | length=2010 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2010 | GC content: 49.95%
# Sequence length (bp): 2010
# Label: DHA2_102322-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Glucosyltransferase | location=AHGT01000012:44286-46991(+) | length=2706 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2706 | GC content: 47.41%
# Sequence length (bp): 2706
# Label: DHA2_102455-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Kinesin motor domain protein | location=AHGT01000022:4002-7586(-) | length=3585 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3585 | GC content: 47.89%
# Sequence length (bp): 3585
# Label: DHA2_10254-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative WD-repeat family protein | location=AHGT01000007:68805-71219(-) | length=2415 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2415 | GC content: 49.94%
# Sequence length (bp): 2415
# Label: DHA2_10255-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Protein Translation Initiation Factor 4A | location=AHGT01000007:71375-72550(-) | length=1176 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1176 | GC content: 51.96%
# Sequence length (bp): 1176
# Label: DHA2_10256-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000007:72753-73349(+) | length=597 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 597 | GC content: 48.07%
# Sequence length (bp): 597
# Label: DHA2_10260-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000007:78443-80680(+) | length=2238 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2238 | GC content: 47.90%
# Sequence length (bp): 2238
# Label: DHA2_10261-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=putative SP-RING zinc finger protein | location=AHGT01000007:80726-82273(+) | length=1548 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1548 | GC content: 45.99%
# Sequence length (bp): 1548
# Label: DHA2_102647-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative sodium/hydrogen antiporter | location=AHGT01000073:26703-29291(-) | length=2589 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2589 | GC content: 49.32%
# Sequence length (bp): 2589
# Label: DHA2_10269-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000007:90325-90945(-) | length=621 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 621 | GC content: 49.11%
# Sequence length (bp): 621
# Label: DHA2_102722-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Preribosomal RNA processing essential GTPase Bms1 | location=AHGT01000017:113502-117383(+) | length=3882 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3882 | GC content: 48.22%
# Sequence length (bp): 3882
# Label: DHA2_102890-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative WD-repeat family protein | location=AHGT01000018:10421-11512(-) | length=1092 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1092 | GC content: 51.56%
# Sequence length (bp): 1092
# Label: DHA2_10291-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000022:105538-108957(-) | length=3420 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3420 | GC content: 46.49%
# Sequence length (bp): 3420
# Label: DHA2_102961-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative alpha/beta hydrolase fold family protein | location=AHGT01000041:52379-54385(-) | length=2007 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2007 | GC content: 50.27%
# Sequence length (bp): 2007
# Label: DHA2_102963-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=(Dimethylallyl)adenosine tRNA methylthiotransferase | location=AHGT01000041:46589-48166(+) | length=1578 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1578 | GC content: 50.89%
# Sequence length (bp): 1578
# Label: DHA2_10297-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative WD-repeat family protein | location=AHGT01000022:100744-102093(+) | length=1350 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1350 | GC content: 48.15%
# Sequence length (bp): 1350
# Label: DHA2_10299-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000022:98904-99557(+) | length=654 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 654 | GC content: 46.94%
# Sequence length (bp): 654
# Label: DHA2_10303-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000022:95162-96361(+) | length=1200 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1200 | GC content: 52.00%
# Sequence length (bp): 1200
# Label: DHA2_103059-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Dynein heavy chain | location=AHGT01000109:5234-12454(+) | length=7221 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 7221 | GC content: 50.66%
# Sequence length (bp): 7221
# Label: DHA2_103074-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative RimK-like ATP-grasp domain protein | location=AHGT01000058:24529-31080(+) | length=6552 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 6552 | GC content: 46.67%
# Sequence length (bp): 6552
# Label: DHA2_10311-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ornithine carbamoyltransferase | location=AHGT01000002:93550-94533(-) | length=984 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 984 | GC content: 60.47%
# Sequence length (bp): 984
# Label: DHA2_10313-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine protein kinase | location=AHGT01000002:94723-95637(+) | length=915 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 915 | GC content: 51.69%
# Sequence length (bp): 915
# Label: DHA2_10315-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000002:96743-97411(-) | length=669 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 669 | GC content: 52.17%
# Sequence length (bp): 669
# Label: DHA2_103164-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000042:29227-30438(+) | length=1212 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1212 | GC content: 55.28%
# Sequence length (bp): 1212
# Label: DHA2_10324-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ribulose-phosphate 3-epimerase | location=AHGT01000002:21719-22444(-) | length=726 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 726 | GC content: 49.45%
# Sequence length (bp): 726
# Label: DHA2_10329-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ferredoxin, 4Fe-4S | location=AHGT01000002:19977-20303(+) | length=327 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 327 | GC content: 51.99%
# Sequence length (bp): 327
# Label: DHA2_103365-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000108:11737-17868(+) | length=6132 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 6132 | GC content: 45.71%
# Sequence length (bp): 6132
# Label: DHA2_10341-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000002:7092-8108(+) | length=1017 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1017 | GC content: 47.49%
# Sequence length (bp): 1017
# Label: DHA2_103437-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000103:8105-9010(-) | length=906 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 906 | GC content: 52.98%
# Sequence length (bp): 906
# Label: DHA2_10358-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Flavoprotein | location=AHGT01000001:432567-433811(+) | length=1245 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1245 | GC content: 52.93%
# Sequence length (bp): 1245
# Label: DHA2_10361-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative AAA family protein | location=AHGT01000001:430058-432004(-) | length=1947 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1947 | GC content: 46.33%
# Sequence length (bp): 1947
# Label: DHA2_10367-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=SSU ribosomal protein S24E | location=AHGT01000056:36138-36536(+) | length=399 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 399 | GC content: 53.38%
# Sequence length (bp): 399
# Label: DHA2_103676-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Tubulin alpha chain | location=AHGT01000004:124699-126234(+) | length=1536 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1536 | GC content: 63.28%
# Sequence length (bp): 1536
# Label: DHA2_10370-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000056:31478-32839(+) | length=1362 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1362 | GC content: 47.28%
# Sequence length (bp): 1362
# Label: DHA2_103713-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Protein disulfide isomerase | location=AHGT01000027:60635-61699(+) | length=1065 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1065 | GC content: 53.05%
# Sequence length (bp): 1065
# Label: DHA2_103783-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ankyrin repeat protein | location=AHGT01000075:476-1192(-) | length=717 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 717 | GC content: 53.70%
# Sequence length (bp): 717
# Label: DHA2_10382-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Tubulin--tyrosine ligase | location=AHGT01000056:16265-17584(+) | length=1320 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1320 | GC content: 48.41%
# Sequence length (bp): 1320
# Label: DHA2_103838-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine protein kinase | location=AHGT01000040:41931-47555(-) | length=5625 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 5625 | GC content: 47.00%
# Sequence length (bp): 5625
# Label: DHA2_104031-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Glycogen [starch] synthase | location=AHGT01000002:284784-287045(-) | length=2262 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2262 | GC content: 49.96%
# Sequence length (bp): 2262
# Label: DHA2_104150-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine-protein kinase PLK | location=AHGT01000021:113652-115751(+) | length=2100 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2100 | GC content: 50.10%
# Sequence length (bp): 2100
# Label: DHA2_104173-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Isoleucyl-tRNA synthetase | location=AHGT01000028:28874-32371(-) | length=3498 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3498 | GC content: 50.40%
# Sequence length (bp): 3498
# Label: DHA2_10422-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000014:26412-27065(-) | length=654 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 654 | GC content: 48.47%
# Sequence length (bp): 654
# Label: DHA2_10423-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hsp90 ATPase activator, N-terminal | location=AHGT01000014:27157-27627(+) | length=471 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 471 | GC content: 47.13%
# Sequence length (bp): 471
# Label: DHA2_104248-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000001:2145-3356(+) | length=1212 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1212 | GC content: 46.95%
# Sequence length (bp): 1212
# Label: DHA2_10425-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000014:27713-28219(+) | length=507 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 507 | GC content: 43.79%
# Sequence length (bp): 507
# Label: DHA2_10428-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=LSU ribosomal protein L10AE | location=AHGT01000014:28569-29201(+) | length=633 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 633 | GC content: 58.29%
# Sequence length (bp): 633
# Label: DHA2_10429-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative p23-like domain protein | location=AHGT01000014:29238-29795(-) | length=558 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 558 | GC content: 54.66%
# Sequence length (bp): 558
# Label: DHA2_10450-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Peptidyl-prolyl cis-trans isomerase | location=AHGT01000011:150294-150623(-) | length=330 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 330 | GC content: 56.06%
# Sequence length (bp): 330
# Label: DHA2_10459-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=RRNA processing Fcf1 Family Protein | location=AHGT01000011:135818-136390(+) | length=573 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 573 | GC content: 49.39%
# Sequence length (bp): 573
# Label: DHA2_104685-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Caltractin | location=AHGT01000042:28557-29087(-) | length=531 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 531 | GC content: 49.91%
# Sequence length (bp): 531
# Label: DHA2_104866-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000024:102528-103112(+) | length=585 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 585 | GC content: 47.18%
# Sequence length (bp): 585
# Label: DHA2_104982-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000018:137944-138291(-) | length=348 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 348 | GC content: 48.28%
# Sequence length (bp): 348
# Label: DHA2_10516-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Leucine carboxyl methyltransferase | location=AHGT01000073:40716-41810(+) | length=1095 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1095 | GC content: 51.32%
# Sequence length (bp): 1095
# Label: DHA2_10521-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Arginyl-tRNA synthetase | location=AHGT01000006:102193-104058(+) | length=1866 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1866 | GC content: 50.96%
# Sequence length (bp): 1866
# Label: DHA2_10522-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000006:104099-104953(-) | length=855 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 855 | GC content: 54.50%
# Sequence length (bp): 855
# Label: DHA2_10524-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000006:105991-106743(+) | length=753 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 753 | GC content: 55.25%
# Sequence length (bp): 753
# Label: DHA2_10527-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000006:107894-108841(+) | length=948 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 948 | GC content: 51.69%
# Sequence length (bp): 948
# Label: DHA2_10529-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative TPR repeat family protein | location=AHGT01000006:109517-110794(-) | length=1278 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1278 | GC content: 49.61%
# Sequence length (bp): 1278
# Label: DHA2_10530-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Vacuolar ATP synthase proteolipid subunit | location=AHGT01000006:110891-111424(+) | length=534 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 534 | GC content: 50.56%
# Sequence length (bp): 534
# Label: DHA2_10538-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Dynein beta chain | location=AHGT01000006:123317-125626(-) | length=2310 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2310 | GC content: 49.83%
# Sequence length (bp): 2310
# Label: DHA2_10552-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative GCC2/GCS3 family protein | location=AHGT01000038:45308-46918(+) | length=1611 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1611 | GC content: 46.93%
# Sequence length (bp): 1611
# Label: DHA2_10568-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000013:135768-136826(+) | length=1059 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1059 | GC content: 45.70%
# Sequence length (bp): 1059
# Label: DHA2_10569-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative KRI1-like family protein | location=AHGT01000013:134175-135692(+) | length=1518 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1518 | GC content: 48.35%
# Sequence length (bp): 1518
# Label: DHA2_10570-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Peptidyl-prolyl cis-trans isomerase | location=AHGT01000013:133080-134144(-) | length=1065 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1065 | GC content: 50.70%
# Sequence length (bp): 1065
# Label: DHA2_10577-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative snoRNA binding domain protein | location=AHGT01000013:123101-124597(-) | length=1497 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1497 | GC content: 50.43%
# Sequence length (bp): 1497
# Label: DHA2_10606-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Poly(A)-specific ribonuclease, CAF1 protein | location=AHGT01000117:4391-5173(+) | length=783 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 783 | GC content: 47.38%
# Sequence length (bp): 783
# Label: DHA2_10608-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000117:5327-8116(-) | length=2790 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2790 | GC content: 50.43%
# Sequence length (bp): 2790
# Label: DHA2_10609-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine protein kinase | location=AHGT01000117:8308-9579(+) | length=1272 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1272 | GC content: 49.84%
# Sequence length (bp): 1272
# Label: DHA2_10612-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Protein phosphatase type 2A phosphotyrosyl phosphatase activator | location=AHGT01000117:12949-13875(-) | length=927 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 927 | GC content: 47.68%
# Sequence length (bp): 927
# Label: DHA2_10661-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ubiquitin-activating enzyme E1 | location=AHGT01000054:4039-7317(-) | length=3279 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3279 | GC content: 47.79%
# Sequence length (bp): 3279
# Label: DHA2_10666-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Histone acetyltransferase, GCN5 family | location=AHGT01000054:9461-10687(-) | length=1227 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1227 | GC content: 51.02%
# Sequence length (bp): 1227
# Label: DHA2_10667-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000054:10742-11215(-) | length=474 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 474 | GC content: 46.20%
# Sequence length (bp): 474
# Label: DHA2_10675-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000040:68370-70739(-) | length=2370 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2370 | GC content: 47.68%
# Sequence length (bp): 2370
# Label: DHA2_10676-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000040:66180-68324(-) | length=2145 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2145 | GC content: 50.68%
# Sequence length (bp): 2145
# Label: DHA2_10679-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Double-stranded DNA-binding domain family protein | location=AHGT01000040:64921-65343(+) | length=423 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 423 | GC content: 50.83%
# Sequence length (bp): 423
# Label: DHA2_10697-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000001:375524-376567(-) | length=1044 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1044 | GC content: 52.11%
# Sequence length (bp): 1044
# Label: DHA2_10698-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000001:372827-375139(+) | length=2313 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2313 | GC content: 48.29%
# Sequence length (bp): 2313
# Label: DHA2_10703-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ankyrin repeat protein | location=AHGT01000001:362374-363522(+) | length=1149 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1149 | GC content: 51.09%
# Sequence length (bp): 1149
# Label: DHA2_10705-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000001:360903-362324(+) | length=1422 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1422 | GC content: 47.96%
# Sequence length (bp): 1422
# Label: DHA2_10707-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=NAD-dependent deacetylase, Sir2 family protein | location=AHGT01000001:358877-360556(+) | length=1680 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1680 | GC content: 51.79%
# Sequence length (bp): 1680
# Label: DHA2_10711-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine protein phosphatase | location=AHGT01000001:352145-353101(+) | length=957 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 957 | GC content: 44.62%
# Sequence length (bp): 957
# Label: DHA2_10756-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative membrane spanning protein | location=AHGT01000046:45046-46038(-) | length=993 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 993 | GC content: 47.43%
# Sequence length (bp): 993
# Label: DHA2_1076-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000103:7016-8053(-) | length=1038 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1038 | GC content: 50.29%
# Sequence length (bp): 1038
# Label: DHA2_10760-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000046:48450-48845(+) | length=396 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 396 | GC content: 51.77%
# Sequence length (bp): 396
# Label: DHA2_10762-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000046:49557-51023(-) | length=1467 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1467 | GC content: 46.97%
# Sequence length (bp): 1467
# Label: DHA2_10765-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=DNA replication licensing factor MCM7 | location=AHGT01000046:53614-55728(-) | length=2115 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2115 | GC content: 47.90%
# Sequence length (bp): 2115
# Label: DHA2_10778-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000046:64704-67781(+) | length=3078 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3078 | GC content: 49.61%
# Sequence length (bp): 3078
# Label: DHA2_10780-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=SSU ribosomal protein S27E | location=AHGT01000046:69767-70141(+) | length=375 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 375 | GC content: 48.27%
# Sequence length (bp): 375
# Label: DHA2_10783-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Thiosulfate sulfurtransferase | location=AHGT01000046:71073-72260(+) | length=1188 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1188 | GC content: 44.28%
# Sequence length (bp): 1188
# Label: DHA2_10804-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000003:195370-196281(-) | length=912 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 912 | GC content: 50.00%
# Sequence length (bp): 912
# Label: DHA2_10808-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000003:191152-191838(+) | length=687 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 687 | GC content: 53.71%
# Sequence length (bp): 687
# Label: DHA2_10810-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000003:190173-191012(-) | length=840 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 840 | GC content: 50.71%
# Sequence length (bp): 840
# Label: DHA2_10813-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000003:181524-188561(-) | length=7038 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 7038 | GC content: 47.26%
# Sequence length (bp): 7038
# Label: DHA2_10829-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Glucosamine-6-phosphate isomerase | location=AHGT01000007:45805-46596(+) | length=792 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 792 | GC content: 58.21%
# Sequence length (bp): 792
# Label: DHA2_10836-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Methyl-accepting chemotaxis protein | location=AHGT01000007:61981-62556(+) | length=576 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 576 | GC content: 46.70%
# Sequence length (bp): 576
# Label: DHA2_10840-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=DNA-directed RNA polymerase I, II, and III, subunit 11 | location=AHGT01000011:77091-77396(+) | length=306 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 306 | GC content: 54.25%
# Sequence length (bp): 306
# Label: DHA2_10843-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine carboxypeptidase S28 | location=AHGT01000011:78602-80170(-) | length=1569 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1569 | GC content: 50.67%
# Sequence length (bp): 1569
# Label: DHA2_10846-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000011:82802-83611(+) | length=810 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 810 | GC content: 47.04%
# Sequence length (bp): 810
# Label: DHA2_10850-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000011:88985-89371(+) | length=387 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 387 | GC content: 55.81%
# Sequence length (bp): 387
# Label: DHA2_10853-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000011:94689-97739(+) | length=3051 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3051 | GC content: 47.33%
# Sequence length (bp): 3051
# Label: DHA2_10856-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000011:99097-99981(+) | length=885 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 885 | GC content: 47.80%
# Sequence length (bp): 885
# Label: DHA2_10858-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000011:100396-101481(-) | length=1086 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1086 | GC content: 49.17%
# Sequence length (bp): 1086
# Label: DHA2_10870-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Aspartyl-tRNA synthetase | location=AHGT01000021:18157-19824(+) | length=1668 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1668 | GC content: 50.06%
# Sequence length (bp): 1668
# Label: DHA2_10875-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000021:23137-25923(+) | length=2787 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2787 | GC content: 48.04%
# Sequence length (bp): 2787
# Label: DHA2_10876-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000021:26042-26884(-) | length=843 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 843 | GC content: 51.01%
# Sequence length (bp): 843
# Label: DHA2_10879-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000021:27842-30301(-) | length=2460 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2460 | GC content: 47.97%
# Sequence length (bp): 2460
# Label: DHA2_10881-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative WD-repeat family protein | location=AHGT01000021:32001-33542(-) | length=1542 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1542 | GC content: 51.23%
# Sequence length (bp): 1542
# Label: DHA2_10882-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000021:33626-34531(-) | length=906 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 906 | GC content: 52.43%
# Sequence length (bp): 906
# Label: DHA2_10883-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative TPR repeat family protein | location=AHGT01000021:34625-35722(-) | length=1098 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1098 | GC content: 49.45%
# Sequence length (bp): 1098
# Label: DHA2_10885-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=4-alpha-glucanotransferase / Amylo-alpha-1,6-glucosidase | location=AHGT01000021:35920-41115(-) | length=5196 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 5196 | GC content: 50.25%
# Sequence length (bp): 5196
# Label: DHA2_10889-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000082:16486-17187(-) | length=702 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 702 | GC content: 48.58%
# Sequence length (bp): 702
# Label: DHA2_10892-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000082:18279-20507(+) | length=2229 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2229 | GC content: 51.19%
# Sequence length (bp): 2229
# Label: DHA2_10893-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine protein kinase | location=AHGT01000082:20546-21511(-) | length=966 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 966 | GC content: 51.55%
# Sequence length (bp): 966
# Label: DHA2_10908-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=WD-40 repeat protein family | location=AHGT01000082:35161-37296(-) | length=2136 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2136 | GC content: 47.24%
# Sequence length (bp): 2136
# Label: DHA2_10911-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ankyrin repeat protein | location=AHGT01000082:37868-41026(+) | length=3159 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3159 | GC content: 50.78%
# Sequence length (bp): 3159
# Label: DHA2_10919-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative plectin/S10 domain protein | location=AHGT01000028:27187-27591(-) | length=405 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 405 | GC content: 52.59%
# Sequence length (bp): 405
# Label: DHA2_10924-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000028:22490-23485(+) | length=996 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 996 | GC content: 51.20%
# Sequence length (bp): 996
# Label: DHA2_10943-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000028:7128-9659(-) | length=2532 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2532 | GC content: 46.80%
# Sequence length (bp): 2532
# Label: DHA2_10969-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=MRP-family nucleotide-binding protein | location=AHGT01000003:44538-45557(+) | length=1020 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1020 | GC content: 49.22%
# Sequence length (bp): 1020
# Label: DHA2_10976-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000003:33351-37619(-) | length=4269 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 4269 | GC content: 47.08%
# Sequence length (bp): 4269
# Label: DHA2_10979-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000003:31736-32728(+) | length=993 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 993 | GC content: 44.91%
# Sequence length (bp): 993
# Label: DHA2_11043-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Fructose-bisphosphate aldolase | location=AHGT01000002:159535-160506(+) | length=972 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 972 | GC content: 54.84%
# Sequence length (bp): 972
# Label: DHA2_11044-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Maintenance of ploidy protein MOB1 | location=AHGT01000002:158833-159468(+) | length=636 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 636 | GC content: 47.96%
# Sequence length (bp): 636
# Label: DHA2_11052-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative zinc finger domain-containing protein | location=AHGT01000058:18000-18836(+) | length=837 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 837 | GC content: 50.30%
# Sequence length (bp): 837
# Label: DHA2_11054-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000058:16524-17873(-) | length=1350 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1350 | GC content: 45.48%
# Sequence length (bp): 1350
# Label: DHA2_11100-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative tetratricopeptide repeat domain protein | location=AHGT01000001:127144-132612(-) | length=5469 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 5469 | GC content: 46.52%
# Sequence length (bp): 5469
# Label: DHA2_11110-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000001:113404-113862(+) | length=459 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 459 | GC content: 44.66%
# Sequence length (bp): 459
# Label: DHA2_11114-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000001:110717-111277(+) | length=561 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 561 | GC content: 50.80%
# Sequence length (bp): 561
# Label: DHA2_11118-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Enolase | location=AHGT01000001:106746-108083(-) | length=1338 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1338 | GC content: 56.58%
# Sequence length (bp): 1338
# ...
# Total length = 402 | GC content: 54.48%
# Sequence length (bp): 402
# Label: DHA2_9529-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative DHHC zinc finger domain protein | location=AHGT01000047:63763-64704(+) | length=942 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 942 | GC content: 47.35%
# Sequence length (bp): 942
# Label: DHA2_9541-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Transport protein particle component Bet3 | location=AHGT01000010:73728-74291(+) | length=564 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 564 | GC content: 52.13%
# Sequence length (bp): 564
# Label: DHA2_9545-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000010:84135-85154(-) | length=1020 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1020 | GC content: 47.16%
# Sequence length (bp): 1020
# Label: DHA2_95549-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ankyrin repeat protein | location=AHGT01000017:117388-119703(-) | length=2316 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2316 | GC content: 48.92%
# Sequence length (bp): 2316
# Label: DHA2_95557-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ankyrin repeat protein | location=AHGT01000017:109117-111534(+) | length=2418 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2418 | GC content: 48.06%
# Sequence length (bp): 2418
# Label: DHA2_9558-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Small GTPase, Rab family domain protein | location=AHGT01000015:155316-155954(-) | length=639 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 639 | GC content: 48.51%
# Sequence length (bp): 639
# Label: DHA2_95593-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine protein kinase | location=AHGT01000017:72959-74089(+) | length=1131 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1131 | GC content: 52.96%
# Sequence length (bp): 1131
# Label: DHA2_95653-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Chromosome segregation protein SMC | location=AHGT01000094:8431-10833(+) | length=2403 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2403 | GC content: 46.57%
# Sequence length (bp): 2403
# Label: DHA2_95661-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Tubulin--tyrosine ligase | location=AHGT01000094:17385-19703(-) | length=2319 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2319 | GC content: 47.39%
# Sequence length (bp): 2319
# Label: DHA2_95693-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000002:66132-66791(-) | length=660 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 660 | GC content: 54.39%
# Sequence length (bp): 660
# Label: DHA2_95717-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine-protein kinase NEK | location=AHGT01000002:57856-60933(+) | length=3078 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3078 | GC content: 48.90%
# Sequence length (bp): 3078
# Label: DHA2_95787-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative Dpy-30 motif protein | location=AHGT01000100:4077-7865(+) | length=3789 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3789 | GC content: 45.76%
# Sequence length (bp): 3789
# Label: DHA2_95880-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000034:21845-23056(+) | length=1212 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1212 | GC content: 47.94%
# Sequence length (bp): 1212
# Label: DHA2_95898-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Superfamily II DNA and RNA helicase | location=AHGT01000034:36437-38170(+) | length=1734 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1734 | GC content: 49.48%
# Sequence length (bp): 1734
# Label: DHA2_95904-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Amino acid transporter | location=AHGT01000034:39210-40889(-) | length=1680 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1680 | GC content: 49.05%
# Sequence length (bp): 1680
# Label: DHA2_9593-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative WD-repeat family protein | location=AHGT01000005:202452-205463(+) | length=3012 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 3012 | GC content: 45.88%
# Sequence length (bp): 3012
# Label: DHA2_9594-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative TPR repeat family protein | location=AHGT01000005:201519-202400(-) | length=882 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 882 | GC content: 49.09%
# Sequence length (bp): 882
# Label: DHA2_9611-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Ribosomal protein S2 | location=AHGT01000003:262962-263567(-) | length=606 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 606 | GC content: 51.65%
# Sequence length (bp): 606
# Label: DHA2_9618-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative leucine-rich repeat protein | location=AHGT01000003:268897-271512(+) | length=2616 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2616 | GC content: 45.45%
# Sequence length (bp): 2616
# Label: DHA2_96399-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000031:94008-99020(+) | length=5013 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 5013 | GC content: 47.00%
# Sequence length (bp): 5013
# Label: DHA2_96460-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Alanyl-tRNA synthetase | location=AHGT01000015:108784-111693(+) | length=2910 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2910 | GC content: 49.79%
# Sequence length (bp): 2910
# Label: DHA2_96537-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=ATP-dependent RNA helicase | location=AHGT01000043:61444-63294(-) | length=1851 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1851 | GC content: 47.38%
# Sequence length (bp): 1851
# Label: DHA2_9658-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Serine/threonine protein kinase | location=AHGT01000097:13141-14052(+) | length=912 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 912 | GC content: 47.15%
# Sequence length (bp): 912
# Label: DHA2_9659-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000097:14101-15915(-) | length=1815 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1815 | GC content: 48.21%
# Sequence length (bp): 1815
# Label: DHA2_96616-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Cyclin-dependent protein kinase | location=AHGT01000050:2574-4274(-) | length=1701 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1701 | GC content: 46.38%
# Sequence length (bp): 1701
# Label: DHA2_96670-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Sodium or proton/potassium antiporter, ATPase alpha subunit | location=AHGT01000074:38459-42649(+) | length=4191 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 4191 | GC content: 47.48%
# Sequence length (bp): 4191
# Label: DHA2_9668-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000097:23889-24374(-) | length=486 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 486 | GC content: 47.94%
# Sequence length (bp): 486
# Label: DHA2_96818-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Nucleoside transporter | location=AHGT01000041:44308-45771(+) | length=1464 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1464 | GC content: 47.20%
# Sequence length (bp): 1464
# Label: DHA2_9698-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Monofunctional riboflavin kinase | location=AHGT01000075:25555-25971(-) | length=417 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 417 | GC content: 46.52%
# Sequence length (bp): 417
# Label: DHA2_96994-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative snare domain protein | location=AHGT01000002:20352-21275(-) | length=924 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 924 | GC content: 46.65%
# Sequence length (bp): 924
# Label: DHA2_9704-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Transketolase | location=AHGT01000075:19131-21290(-) | length=2160 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2160 | GC content: 51.02%
# Sequence length (bp): 2160
# Label: DHA2_9705-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative yeats family protein | location=AHGT01000075:18241-19053(+) | length=813 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 813 | GC content: 51.17%
# Sequence length (bp): 813
# Label: DHA2_9718-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Small guanosine triphosphatase, Ras-related family | location=AHGT01000037:24332-25003(+) | length=672 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 672 | GC content: 46.88%
# Sequence length (bp): 672
# Label: DHA2_9719-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=NADH-dependent flavin oxidoreductase | location=AHGT01000037:25092-26381(+) | length=1290 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1290 | GC content: 50.70%
# Sequence length (bp): 1290
# Label: DHA2_97219-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Fibrillarin | location=AHGT01000006:125999-126982(+) | length=984 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 984 | GC content: 59.04%
# Sequence length (bp): 984
# Label: DHA2_9741-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=ABC transporter ATP-binding protein | location=AHGT01000005:36273-38618(+) | length=2346 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2346 | GC content: 48.42%
# Sequence length (bp): 2346
# Label: DHA2_9750-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Chromosome segregation protein SMC | location=AHGT01000005:45723-47432(-) | length=1710 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1710 | GC content: 50.18%
# Sequence length (bp): 1710
# Label: DHA2_9751-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Molecular chaperones (DnaJ family) | location=AHGT01000005:47464-48507(+) | length=1044 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1044 | GC content: 47.22%
# Sequence length (bp): 1044
# Label: DHA2_9755-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000005:55038-55673(+) | length=636 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 636 | GC content: 47.48%
# Sequence length (bp): 636
# Label: DHA2_9778-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=GTP-binding protein TEM1 | location=AHGT01000039:71001-71591(-) | length=591 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 591 | GC content: 51.44%
# Sequence length (bp): 591
# Label: DHA2_9779-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Uridine phosphorylase | location=AHGT01000039:69934-70866(-) | length=933 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 933 | GC content: 58.74%
# Sequence length (bp): 933
# Label: DHA2_9780-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000039:69157-69906(-) | length=750 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 750 | GC content: 54.27%
# Sequence length (bp): 750
# Label: DHA2_9782-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000039:68379-69146(+) | length=768 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 768 | GC content: 55.73%
# Sequence length (bp): 768
# Label: DHA2_9803-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=RNA binding protein | location=AHGT01000042:12574-13620(-) | length=1047 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1047 | GC content: 51.19%
# Sequence length (bp): 1047
# Label: DHA2_98054-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Heat shock protein 90 | location=AHGT01000054:55144-56274(+) | length=1131 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1131 | GC content: 57.47%
# Sequence length (bp): 1131
# Label: DHA2_98056-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=LSU ribosomal protein L22P | location=AHGT01000005:32018-32512(+) | length=495 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 495 | GC content: 57.78%
# Sequence length (bp): 495
# Label: DHA2_9808-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Chaperone protein dnaJ | location=AHGT01000042:21436-22665(-) | length=1230 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1230 | GC content: 54.23%
# Sequence length (bp): 1230
# Label: DHA2_9810-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=LSU ribosomal protein L44E | location=AHGT01000042:22768-23097(-) | length=330 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 330 | GC content: 54.24%
# Sequence length (bp): 330
# Label: DHA2_9824-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Proteasome protease subunit | location=AHGT01000008:105663-106328(+) | length=666 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 666 | GC content: 49.10%
# Sequence length (bp): 666
# Label: DHA2_9827-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Thioredoxin reductase | location=AHGT01000008:102642-103586(-) | length=945 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 945 | GC content: 59.05%
# Sequence length (bp): 945
# Label: DHA2_9850-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000069:36103-37026(-) | length=924 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 924 | GC content: 59.09%
# Sequence length (bp): 924
# Label: DHA2_9894-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000015:75762-78440(-) | length=2679 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2679 | GC content: 47.48%
# Sequence length (bp): 2679
# Label: DHA2_9896-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000015:78614-78997(-) | length=384 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 384 | GC content: 46.88%
# Sequence length (bp): 384
# Label: DHA2_9899-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000015:79541-81127(+) | length=1587 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1587 | GC content: 48.71%
# Sequence length (bp): 1587
# Label: DHA2_9900-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Putative membrane spanning protein | location=AHGT01000015:81145-82014(-) | length=870 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 870 | GC content: 49.20%
# Sequence length (bp): 870
# Label: DHA2_9909-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Pyruvate,phosphate dikinase | location=AHGT01000015:86692-89346(+) | length=2655 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 2655 | GC content: 55.63%
# Sequence length (bp): 2655
# Label: DHA2_9913-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000015:92517-93875(+) | length=1359 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 1359 | GC content: 48.93%
# Sequence length (bp): 1359
# Label: DHA2_9916-t26_1 | organism=Giardia_Assemblage_A2_isolate_DH | product=Hypothetical protein | location=AHGT01000015:95660-96301(+) | length=642 | sequence_SO=contig | SO=protein_coding_gene
# Total length = 642 | GC content: 48.13%
# Sequence length (bp): 642
